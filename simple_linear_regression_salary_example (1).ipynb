# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
data_path = 'Salary_Data.csv'
data = pd.read_csv(data_path)

# Split the dataset into features and target variable
X = data.iloc[:, :-1].values  # All rows, all columns except the last one
y = data.iloc[:, -1].values   # All rows, just the last column

# Splitting dataset into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Creating a simple linear regression model
regressor = LinearRegression()

# Training the model
regressor.fit(X_train, y_train)

# Making predictions on the test set
y_pred = regressor.predict(X_test)

# Evaluating the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared score: {r2}")

# Visualizing the training set results
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(X_train, y_train, color='red', label='Actual')
plt.plot(X_train, regressor.predict(X_train), color='blue', label='Predicted')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()

# Visualizing the test set results
plt.subplot(1, 2, 2)
plt.scatter(X_test, y_test, color='red', label='Actual')
plt.plot(X_train, regressor.predict(X_train), color='blue', label='Prediction Line')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.tight_layout()
plt.show()

# Print the model equation
intercept = regressor.intercept_
slope = regressor.coef_[0]
print(f"The linear model is: Salary = {slope:.2f} * YearsExperience + {intercept:.2f}")

# Make a prediction for 2.5 years of experience
years_experience = np.array([[2.5]])
predicted_salary = regressor.predict(years_experience)
print(f"Predicted salary for someone with 2.5 years of experience is: ${predicted_salary[0]:.2f}")
# Out:
# Mean Absolute Error (MAE): 2446.1723690465055
# Mean Squared Error (MSE): 12823412.298126549
# R-squared score: 0.988169515729126
# The linear model is: Salary = 9312.58 * YearsExperience + 26780.10
# Predicted salary for someone with 2.5 years of experience is: $50061.54

# %% [markdown]
# Mean Absolute Error (MAE): 2446.1723690465055
# Mean Squared Error (MSE): 12823412.298126549
# R-squared score: 0.988169515729126
#
# These metrics indicate that the model performs quite well in predicting the Salary based on YearsExperience, with a high R-squared score of 0.988, suggesting that the model explains 98.8% of the variability in the dependent variable. The MAE and MSE provide a sense of the average error in the salary predictions.
